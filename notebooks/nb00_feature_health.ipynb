# %%
import subprocess\nimport sys\nfrom pathlib import Path\n\nEXPORT_DIR = Path('/kaggle/input/northstar-v3-export/00_export')\nOUTPUT_DIR = Path('/kaggle/working/nb00_feature_health')\n

# %%
subprocess.run([\n    sys.executable,\n    '/kaggle/input/northstar-v3-code/scripts/kaggle/week_2026_03_29/nb00_feature_health.py',\n    '--export-dir', str(EXPORT_DIR),\n    '--output-dir', str(OUTPUT_DIR),\n], check=True)\n
